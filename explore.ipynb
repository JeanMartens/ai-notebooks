# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os 
import imageio
import re

# %%
def create_animation(images_path):
    filenames = os.listdir(images_path)
    filenames = [filename for filename in filenames if filename != '.ipynb_checkpoints']
    filenames.sort(key=lambda x: int(re.search(r"plot_epoch_(\d+).png", x).group(1)))
    
    images = [imageio.imread(os.path.join(images_path, filename)) for filename in filenames]
    imageio.mimsave('results/SATELLITE.gif', images, duration=10)
    return filenames

# %%
filenames = create_animation('saved_plots/SATELLITE_PIX2PIX/')
# Out:
# /tmp/ipykernel_159/3587525298.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images = [imageio.imread(os.path.join(images_path, filename)) for filename in filenames]
# ['plot_epoch_0.png',
#  'plot_epoch_1.png',
#  'plot_epoch_2.png',
#  'plot_epoch_3.png',
#  'plot_epoch_4.png',
#  'plot_epoch_5.png',
#  'plot_epoch_6.png',
#  'plot_epoch_7.png',
#  'plot_epoch_8.png',
#  'plot_epoch_9.png',
#  'plot_epoch_10.png',
#  'plot_epoch_11.png',
#  'plot_epoch_12.png',
#  'plot_epoch_13.png',
#  'plot_epoch_14.png',
#  'plot_epoch_15.png',
#  'plot_epoch_16.png',
#  'plot_epoch_17.png',
#  'plot_epoch_18.png',
#  'plot_epoch_19.png',
#  'plot_epoch_20.png',
#  'plot_epoch_21.png',
#  'plot_epoch_22.png',
#  'plot_epoch_23.png',
#  'plot_epoch_24.png',
#  'plot_epoch_25.png',
# ...
